# %% [markdown]
# ## Task 4: YouTube Video Downloader

# %%
from pytube import YouTube
import os

url = input("Enter YouTube video URL: ")
save_path = input("Enter folder path to save video: ")

try:
    yt = YouTube(url)

    print("Title:",yt.title)
    print("Downloading...")

    stream = yt.streams.get_highest_resolution()

    stream.download(output_path=save_path)

    print("Download completed successfully!")

except Exception as e:
    print("Error occurred!")
    print("Reason:", str(e))
# Out:
# Enter YouTube video URL:  https://youtu.be/zBjJUV-lzHo?si=UkdAo1X4gZv6CTVD
# Enter folder path to save video:  C:\Users\Lenovo\Desktop\Files
# Error occurred!
# Reason: HTTP Error 400: Bad Request
